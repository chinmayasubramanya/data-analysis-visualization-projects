# %%
import matplotlib.pyplot as plt

months = [
    "Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"]

sales = [12000,15000,17000,16000,18000,20000,22000,21000,19000,23000,25000,27000]
print("Monthly Sales Data:")
print(sales)

plt.figure(figsize=(10, 6))

plt.plot(
    months,
    sales,
    marker="o",
    linestyle="-",
    linewidth=2,
    label="Monthly Sales"
)

plt.title("Monthly Sales Trend (2025)")
plt.xlabel("Month")
plt.ylabel("Sales Amount ($)")
plt.legend()
plt.grid(True)
plt.show()

# bar
plt.figure(figsize=(10, 6))

plt.bar(
    months,
    sales,
    label="Monthly Sales"
)

plt.title("Monthly Sales Comparison")
plt.xlabel("Month")
plt.ylabel("Sales Amount ($)")

plt.legend()
plt.grid(True)

plt.show()
# Out:
# Monthly Sales Data:
# [12000, 15000, 17000, 16000, 18000, 20000, 22000, 21000, 19000, 23000, 25000, 27000]
